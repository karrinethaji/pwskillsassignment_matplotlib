# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Matplotlib is a plotting library for the python programming language and its numerical mathmatics extension numpy. It provide an object oriented API for embedding plots into applications using general-purpose GUI toolkits using Tkinter,Wxpython etc.,
#
# **Advantages of using matplotlib:**
#
# Generally easy to get started
# Easy to plot the simple plots
# Supports for the custom labels and texts
# Great control of every element in a figure
# High quality of output in many formats
#
# The five plots which are created using pyplot library is:
#
# 1. bar plot
# 2. scatter plot
# 3. line plot
# 4. box plot
# 5. hist plot

# %% [markdown]
# #### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
#Note: Also add title, xlabel, and ylabel to the plot.

# %%
plt.scatter(x,y)
plt.xlabel("This is x-axis")
plt.ylabel("This is y-axis")
plt.title("This is title")
plt.show()

# %% [markdown]
# #### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.Use the following data:

# %%
# subplot() is used to create the multiple sub plots for the different data at the same time.

import numpy as np

# %% [markdown]
# #### For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# ####   For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# #### For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# #### For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])

plt.subplot(2,2,1)
plt.plot(x,y)

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

plt.subplot(2,2,2)
plt.plot(x2,y2,color="red")

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

plt.subplot(2,2,3)
plt.plot(x3,y3,"--")

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2,2,4)
plt.plot(x4,y4)
plt.grid()

# %% [markdown]
# #### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
plt.show()

# %%
plt.barh(company,profit)
plt.show()

# %% [markdown]
# #### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Box plot is used find the 25%, 50% (median), 75% perecntile value of the data and used to detect the outliers which are present
# under data.

# %%
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28e526440a0>,
#   <matplotlib.lines.Line2D at 0x28e52644340>],
#  'caps': [<matplotlib.lines.Line2D at 0x28e526445e0>,
#   <matplotlib.lines.Line2D at 0x28e52644880>],
#  'boxes': [<matplotlib.lines.Line2D at 0x28e52613e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x28e52644b20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28e525f4550>],
#  'means': []}

# %%
plt.boxplot(x=box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28e51d2e6e0>,
#   <matplotlib.lines.Line2D at 0x28e51d2ed10>],
#  'caps': [<matplotlib.lines.Line2D at 0x28e51d2f190>,
#   <matplotlib.lines.Line2D at 0x28e51d2f6a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x28e51d2e260>],
#  'medians': [<matplotlib.lines.Line2D at 0x28e51d2f400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28e51d2e3e0>],
#  'means': []}
